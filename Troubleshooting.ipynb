# %%
from pyspark.sql import DataFrame
from pyspark.sql import functions as F
from functools import reduce
from pyspark.sql.types import *
import pandas as pd

# %%
# %run Project2_Part1_WarrenE.py

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('my_app').config('spark.sql.ansi.enabled', 'false').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/27 11:42:02 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import numpy as np
import pandas as pd
import pyspark.pandas as ps
pdf = pd.read_csv("fakedata.csv")
pdf.head()
# Out:
# /opt/tljh/user/envs/pySpark3/lib/python3.9/site-packages/pyspark/pandas/__init__.py:43: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(
#    numvar stringvar
# 0      10         a
# 1       2         b
# 2       4         c
# 3      18         d

# %%
df = spark.createDataFrame(pdf)
df.show(2)
# Out:
# +------+---------+
# |numvar|stringvar|
# +------+---------+
# |    10|        a|
# |     2|        b|
# +------+---------+
# only showing top 2 rows

# %%
col_types = df.dtypes
col_types
# Out:
# [('numvar', 'bigint'), ('stringvar', 'string')]

# %%
import Project2_Part1_WarrenE

# %%
import importlib
importlib.reload(Project2_Part1_WarrenE)
# Out:
# <module 'Project2_Part1_WarrenE' from '/home/jupyter-eawarre7@ncsu.edu/Project2_Part1_WarrenE.py'>

# %%
this_df = Project2_Part1_WarrenE.SparkDataCheck.from_pandas(spark, pdf)

# %%
this_df.df.show(3)
# Out:
# +------+---------+
# |numvar|stringvar|
# +------+---------+
# |    10|        a|
# |     2|        b|
# |     4|        c|
# +------+---------+
# only showing top 3 rows

# %%
this_df.check_missing("numvar").df.show(4)
# Out:
# +------+---------+---------+
# |numvar|stringvar|isMissing|
# +------+---------+---------+
# |    10|        a|    false|
# |     2|        b|    false|
# |     4|        c|    false|
# |    18|        d|    false|
# +------+---------+---------+

# %%
this_df.df.dtypes
# Out:
# [('numvar', 'bigint'), ('stringvar', 'string')]

# %%
this_df.check_string("stringvar", ["a"])
# Out:
# Column<'stringvar['dtype']'>
# Supplied column is not string type. No changes have been made to the dataframe.
